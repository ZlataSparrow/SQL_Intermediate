# %%
import os

# Set Java 17 for PySpark
os.environ['JAVA_HOME'] = '/opt/homebrew/opt/openjdk@17/libexec/openjdk.jdk/Contents/Home'
os.environ['PATH'] = '/opt/homebrew/opt/openjdk@17/bin:' + os.environ.get('PATH', '')

from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder.appName("ReadingJSONFiles").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/08 13:44:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/08 13:44:45 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
data_path = '/Users/zlatavorobeva/Documents/GitHub/SQL Int/SQL_Intermediate/Spark/Data'

# %%
json_df1_path = data_path + "/location_temp.json"
df1 = spark.read.format("json").load(json_df1_path)

# %%
json_df2_path = data_path + "/utilization.json"
df2 = spark.read.format("json").load(json_df2_path)

# %%
df1.count()
# Out:
# 500000

# %%
df1.head(10)
# Out:
# [Row(event_date='03/04/2019 19:48:06', location_id='loc0', temp_celcius='29'),
#  Row(event_date='03/04/2019 19:53:06', location_id='loc0', temp_celcius='27'),
#  Row(event_date='03/04/2019 19:58:06', location_id='loc0', temp_celcius='28'),
#  Row(event_date='03/04/2019 20:03:06', location_id='loc0', temp_celcius='30'),
#  Row(event_date='03/04/2019 20:08:06', location_id='loc0', temp_celcius='27'),
#  Row(event_date='03/04/2019 20:13:06', location_id='loc0', temp_celcius='27'),
#  Row(event_date='03/04/2019 20:18:06', location_id='loc0', temp_celcius='27'),
#  Row(event_date='03/04/2019 20:23:06', location_id='loc0', temp_celcius='29'),
#  Row(event_date='03/04/2019 20:28:06', location_id='loc0', temp_celcius='32'),
#  Row(event_date='03/04/2019 20:33:06', location_id='loc0', temp_celcius='35')]

# %%
df2.count()
# Out:
# 500000

# %%
df2.show()
# Out:
# +---------------+-------------------+-----------+---------+-------------+
# |cpu_utilization|     event_datetime|free_memory|server_id|session_count|
# +---------------+-------------------+-----------+---------+-------------+
# |           0.57|03/05/2019 08:06:14|       0.51|      100|           47|
# |           0.47|03/05/2019 08:11:14|       0.62|      100|           43|
# |           0.56|03/05/2019 08:16:14|       0.57|      100|           62|
# |           0.57|03/05/2019 08:21:14|       0.56|      100|           50|
# |           0.35|03/05/2019 08:26:14|       0.46|      100|           43|
# |           0.41|03/05/2019 08:31:14|       0.58|      100|           48|
# |           0.57|03/05/2019 08:36:14|       0.35|      100|           58|
# |           0.41|03/05/2019 08:41:14|        0.4|      100|           58|
# |           0.53|03/05/2019 08:46:14|       0.35|      100|           62|
# |           0.51|03/05/2019 08:51:14|        0.6|      100|           45|
# ...

# %%
df2.columns
# Out:
# ['cpu_utilization',
#  'event_datetime',
#  'free_memory',
#  'server_id',
#  'session_count']
